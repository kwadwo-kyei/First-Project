# %%
#STrenght coaching
from sys import exit
from random import randint
import time

"""
    DocString:
    
    A) Introduction:
    This game is based in a gym where you guide prospective customers as they
    aim to acheive their respective fitness goals. It consists of three 
    customers, and also has defined functions
    for start, win, and lose. This game requires having knowledge of the 
    fitness industry.
    
    Round 1: Decide who to coach.
    Round 2: Guide them on the first week as they seek to acheive their goals.
    Round 3: Guide them on the second week as they seek to acheive their goals
    Round 4:Guide them on the third week as they seek to acheive their goals
    
    B) Known Bugs and/or Errors:
    None.
    
"""
#Countdown function to count down to the start of the game
def countdown(t):   
    input('<Press any key to continue>\n')
    print("Are you ready to begin your career as a fitness trainer? Let the countdown begin\n")
   
#While function to create the time loop   
    while t: 
        mins, secs = divmod(t, 60) 
        timer = '{:02d}:{:02d}'.format(mins, secs) 
        print(timer, end="\r") 
        time.sleep(1) 
        t -= 1
      
    print('Lets Go!!!') 
  
  
# input time in seconds 
t = 5
  
# function call 
countdown(int(t)) 
 
#Definiton function to print my game title and start the game
def STRG():
        print ("Get Fit Inc.\n")
        input('<Press any key to continue>\n')
        Step_0()


#Define function to introduce the game    
def Step_0():
        print("Hello and welcome to the Get Fit Game\n")
        input('<Press any key to continue>\n')
        print("In this game you would be giving the opportunity to help a virtual character acheive their fitness goals by providing fitness exercises that would help them acheive their fitness goals within a three week training periood.\n")



#Define function to introduce your customers   
        input('<Press any key to continue>\n')
        print("Let now introduce you to our participants\n")
        time.sleep(2)
        print("Our first COntestant is Kyle, Kyle weighs 150 pounds and needs your help in acheiving a mored defined arm\n"
              "Our second contestant is Charlie, Charlie weighs 200 pounds and wants to acheive a well rounded back muscle\n"
              "And our last contestant is Sarah who weighs 200 pounds and needs your help in losing weight.\n")
        input('<Press any key to continue>\n')


        print("""
              Choose your contestant:
              1)Kyle-150
              2)Charlie-200
              3)Sarah-240
              """)
        choice = input(">  \n")

#If function direct the player to the contestant of their choice
#Kyle function
        if "1" in choice or "Kyle" in choice:
                print("\nKyle would really appreciate your help!\n")
                input("<Press enter to continue>\n")
                Step_1()
#Charlie function
        elif "2" in choice or "Charlie" in choice:
                print("""\nCharlie would appreciate your help in pushing him to the next stage of his bodybuilding career""")
                input("<Press enter to continue>\n")
                Charlie()
#Sarah function
        elif "3" in choice or "Sarah" in choice:
                print("""\nSarah is running out of time, help her achieve her weight goal before she gets married""")
                Sarah()

        else:
                print("Invalid command. Please try again.")
                input("<Press enter to continue>\n")
                Step_0()
#Kyle's First Game Step
def Step_1():

        print("""
          Kyle is ready for his first workout with you, what exercise would you have him start off with?:
          1)Hit the treadmil for 30 minutes
          2)50 bicep Curls Rep
          3)Crossfit exercises
          """)
        choice_1 = input(">  \n")

        if "1" in choice_1 or "Hit the treadmil for 30 minutes" in choice_1:
            print("Well Kyle just lost 20 pounds\n")
            input("<Press enter to continue>\n")
            print("You have been fired by Kyle. Goodbye!\n")
            print("Would you like to start over?\n")
            kye=input(">  \n")
            if "yes" in kye:
                Step_0()
            else:
                exit(0)

        elif "2" in choice_1:
            print("""\nGreat Choice you really know what you are doing. Thanks to you Kyle is now closer than ever in acheiveing his goal""")
            input("<Press enter to continue>\n")
            Kyle_1()

        elif "3" in choice_1:
            print("""\nNot a good start but we are off to somewhere. Kyle is looking forward to the next training session""")
            Kyle_2()

        else:
            print("Invalid command. Please try again.")
            input("<Press enter to continue>\n")
            Step_1()
#Kyle's Second Step        
def Kyle_1():
    
            print("Congrats!!!Kyle likes his new look and is looking forward to the next session.")
            time.sleep(1)
            print("""
            Kyle is ready for his second workout with you. He is currently feeling great about the size of his amrs and would like to keep the momentum going. Please dont fail Kyle, what is Kyle's next exercise?:
            1)Bench Press 255 ponds
            2)Perform 10 Pull-ups
            3)Spend 40 minutes on ab exercises
            """)
            choice_2 = input(">  \n")

            if "1" in choice_2 or "Bench Press 225 pounds" in choice_2:
                    print("\nGood Job!, Kyle is seeing progress and cant wait to see what you have in store for him next week. COngrats\n")
                    input("<Press enter to continue>\n")
                    Kyle_3()

            elif "2" in choice_2 or "Perform 10 Pull-ups" in choice:
                    print("""\nBad choice Kyle pulled a bicep muscle and...""")
                    input("<Press enter to continue>\n")
                    print("\nKyle has decided to fire you. Goodbye!\n")
                    print("Would you like to start over?\n")
                    kye_1=input(">  \n")
                    if "yes" in kye_1:
                        Step_0()
                    else:
                        exit(0)

            elif "3" in choice_2 or "Spend 40 minutes on ab exercises" in choice:
                    print("""\nKyle is furious he has seen no progress and...""")
                    print("\nHas decided to let you go. Goodbye!\n")
                    print("Would you like to start over?\n")
                    kye_2=input(">  \n")
                    if "yes" in kye_2:
                        Step_0()
                    else:
                        exit(0)

            else:
                    print("Invalid command. Please try again.")
                    input("<Press enter to continue>\n")
                    Kyle_1()
#Kyle's 3rd Step
def Kyle_2():
    
            print("Congrats!!!Kyle is seeing slight progress and has decided to give your session another go")
            input("<Press enter to continue>\n")
            print("""
            Kyle is ready for his second workout with you. He has thought of firing you but decided to give you another chance. Please dont fail Kyle, what is Kyle's next exercise?:
            1)Hammer Curls
            2)Shoulder Press 135 pounds
            3)Swim a mile
            """)

            choice_3 = input(">  \n")

            if "1" in choice_3 or "" in choice_3:
                    print("\nGood comeback, you have been able to regain Kyle's confidence and have boosted his morale\n")
                    input("<Press enter to continue>\n")
                    Kyle_3()


            elif "2" in choice_3 or "Charlie" in choice:
                    print("""\nBad choice Kyle has seen no progress""")
                    input("<Press enter to continue>\n")
                    print("\nYou have been fired by Kyle. Goodbye!\n")
                    print("Would you like to start over?\n")
                    kye_3=input(">  \n")
                    if "yes" in kye_3:
                        Step_0()
                    else:
                        exit(0)

            elif "3" in choice_3 or "Sarah" in choice:
                    print("""\nKyle is furious, he regrets wasting his time with you but wait...""")
                    input("<Press enter to continue>\n")
                    print("\nYou have been fired by Kyle. Goodbye!\n")
                    print("Would you like to start over?\n")
                    kye_4=input(">  \n")
                    if "yes" in kye_4:
                        Step_0()
                    else:
                        exit(0)

            else:
                    print("Invalid command. Please try again.")
                    input("<Press enter to continue>\n")
                    Kyle_2()


        
#Kyle's 4th Step        
def Kyle_3():   
            print("""
            It is Kyle's final week with you. What do you have planned?:
            1)Bench Press 300 pounds
            2)Deadlift 400 pounds
            3)RPF 1000
            """)

            choice_4 = input(">  \n")

            if "1" in choice_4:
                    print("\Kyle has been able to acheive a well rounded bicep. Great Job\n")
                    input("<Press enter to continue>\n")
                    print("Congrats on your achievement with your first client. Charlie has heard of your great success with his fellow friend Kyle and has requested that you also help him acheive his goal of increasing his back muscle mass.\n")
                    print("Type Yes to help Charlie or no to exit the game.\n")
                    Answer=input(">")
                    if "Yes" in Answer or "yes" in Answer:
                        Charlie()
                    else:
                        print("Thank you for your service and Have a good day!")
                        exit(0)

            elif "2" in choice_4:
                    print("""\nWrong decision:)""")
                    input("<Press enter to continue>\n")
                    print("\nYou are fired!!!. Goodbye!\n")
                    print("Would you like to start over?\n")
                    kye_5=input(">  \n")
                    if "yes" in kye_5:
                        Step_0()
                    else:
                        exit(0)

            elif "3" in choice_4:
                    print("""\nKyle has something to tell you:)""")
                    input("<Press enter to continue>\n")
                    print("\nYou are fired!!!. Goodbye!\n")
                    print("Would you like to start over?\n")
                    kye_6=input(">  \n")
                    if "yes" in kye_6:
                        Step_0()
                    else:
                        exit(0)

            else:
                    print("Invalid command. Please try again.")
                    input("<Press enter to continue>\n")
                    Kyle_3()

#Charlie's first step function        
def Charlie():
            print("""
            As Charlie's is now in your hands, what would you like him to start off with?
            1) Rest for an hour then work on cardio for 30 minutes
            2) Work on his legs
            3)Go straight into working on barbell rows
            """)

            bhoice = input(">  \n")

            if "1" in bhoice:
                    print("\nCHarlie has lost faith in your capabilities and has decided to let you go\n")
                    input("<Press enter to continue>\n")
                    print("Would you like to start over?\n")
                    kye_7=input(">  \n")
                    if "yes" in kye_7:
                        Step_0()
                    else:
                        exit(0)

            elif "2" in bhoice:
                    print("\nCHarlie has lost faith in your capabilities and has decided to let you go\n")
                    input("<Press enter to continue>\n")
                    print("Would you like to start over?\n")
                    kye_8=input(">  \n")
                    if "yes" in kye_8:
                        Step_0()
                    else:
                        exit(0)

            elif "3" in bhoice:
                    print("\We are off to a great start and CHarlie has faith in your capabilities!\n")
                    Charlie_1()

            else:
                    print("Invalid command. Please try again.")
                    input("<Press enter to continue>\n")
                    Charlie()
#Charlie's second step function         
def Charlie_1():
            print("""
            Charlie is now in his second week with you, what would you like him
            to start off with?
            1) Push-ups
            2) Jumping Jacks
            3) Deadlifts
            """)

            bhoice_1 = input(">  \n")

            if "1" in bhoice_1:
                    print("\nCHarlie has lost faith in your capabilities and has decided to let you go\n")
                    input("<Press enter to continue>\n")
                    print("Would you like to start over?\n")
                    kye_9=input(">  \n")
                    if "yes" in kye_9:
                        Step_0()
                    else:
                        exit(0)

            elif "2" in bhoice_1:
                    print("\nCHarlie thinks you are a joke and has decided to let you go\n")
                    input("<Press enter to continue>\n")
                    print("Would you like to start over?\n")
                    kyei_1=input(">  \n")
                    if "yes" in kyei_1:
                        Step_0()
                    else:
                        exit(0)

            elif "3" in bhoice_1:
                    print("\We are off to a great start and CHarlie has faith in your capabilities!\n")
                    Charlie_2()

            else:
                    print("Invalid command. Please try again.")
                    input("<Press enter to continue>\n")
                    Charlie_1()
#Charlie's third step function                
def Charlie_2():
            print("""
            We are in CHarlie's final week. He has soo much faith in you, DO not
            let him down. What should he start off with?
            1) Shoulder Press
            2) Pull-Ups
            3) Chest Flys
            """)

            bhoice_1 = input(">  \n")

            if "1" in bhoice_2:
                    print("\nCharlie is dissapointed\n")
                    input("<Press enter to continue>\n")
                    print("\nHe vows never to seek your services again!")
                    print("Would you like to start over?\n")
                    kyei_2=input(">  \n")
                    if "yes" in kyei_2:
                        Step_0()
                    else:
                        exit(0)

            elif "2" in bhoice_2:
                    print("""\Yes!!! Charlie has finally developed his back muscles
                          and he has no one to thank but you. Congrats\n""")
                    time.sleep(1)
                    print("""\nWould you like to help Sarah? She is desperate and 
                          needs to lose weigh for her wedding in 3 weeks.""")
                    Answer_1=input(">")
                    if "Yes" in Answer_1 or "yes" in Answer_1:
                        Sarah()
                    else:
                        print("Thank you for your service and Have a good day!")
                        exit(0)


            elif "3" in bhoice_2:
                    print("""\Bad choice Charlie now has a smaller back thanks to 
                          your horrendous fitness knowledge!\n""")
                    print("Would you like to start over?\n")
                    kyei_3=input(">  \n")
                    if "yes" in kyei_3:
                        Step_0()
                    else:
                        exit(0)

            else:
                    print("Invalid command. Please try again.")
                    input("<Press enter to continue>\n")
                    Charlie_1()
                      
#Sarah's first Step        
def Sarah():
            print("""
            Today marks Sarah's first week with you and she is looking forward to seeing 
            positive changes to her body. What should she start off with?
            1) 1 Mile Run
            2) Jumping Jacks
            3) Barbell Curls
            """)

            Shoice = input(">  \n")

            if "1" in Shoice:
                    print("\nSarah is feeling inspired and in great shape, she is ready for the next obstacle\n")
                    time.sleep(5)
                    print("\nSarah has lost 20 pounds and wants to continue")
                    input("<Press enter to continue>\n")
                    Sarah_1()

            elif "2" in Shoice:
                    print("\nSarah has lost faith in your capabilities and has decided to let you go\n")
                    input("<Press enter to continue>\n")
                    print("Would you like to start over?\n")
                    kyei_4=input(">  \n")
                    if "yes" in kyei_4:
                        Step_0()
                    else:
                        exit(0)

            elif "3" in Shoice:
                    print("\You have been fired, Sarah gained an extra 10 pounds\n")
                    print("Would you like to start over?\n")
                    kyei_5=input(">  \n")
                    if "yes" in kyei_5:
                        Step_0()
                    else:
                        exit(0)

            else:
                    print("Invalid command. Please try again.")
                    input("<Press enter to continue>\n")
                    Sarah()
#Sarah's Second Step       
def Sarah_1():
            print("""
            It's Sarah's second week and she feels ready to go. What would her next task be?
            1) Jump Rope
            2) Barbell Shrugs
            3) Bar Crunch
            """)

            Shoice_1 = input(">  \n")

            if "1" in Shoice_1:
                    print("\nSarah just lost an extra 20 pounds and is speechless. She now weighs 160 pounds\n")
                    time.sleep(5)
                    print("\nSarah is looking forward to the last week with you")
                    input("<Press enter to continue>\n")
                    Sarah_2()

            elif "2" in Shoice_1:
                    print("\nSarah isnt happy with her current weight and has decided to...\n")
                    time.sleep(2)
                    print("\nFire you. She wishes you goodluck in your future endeavours.")
                    print("Would you like to start over?\n")
                    kyei_6=input(">  \n")
                    if "yes" in kyei_6:
                        Step_0()
                    else:
                        exit(0)

            elif "3" in Shoice_1:
                    print("\You have been fired by Sarah, she hasnt seen any improvements in her weight.\n")
                    print("Would you like to start over?\n")
                    kyei_7=input(">  \n")
                    if "yes" in kyei_7:
                        Step_0()
                    else:
                        exit(0)

            else:
                    print("Invalid command. Please try again.")
                    input("<Press enter to continue>\n")
                    Sarah_1()  
#Sarah's third Step                           
def Sarah_2():
            print("""
            Sarah is finally on her last week with you, She is hoping to acheive her weigh goal of 150 pounds. What should her final exercise be?
            1) Barbell rollout
            2) Cycling
            3) Tennis
            """)

            Shoice_2 = input(">  \n")

            if "1" in Shoice_2:
                    print("\nSarah's weight increased by 10 pounds and has decided to leave with immediate effect.\n")
                    input("<Press enter to continue>\n")
                    print("Would you like to start over?\n")
                    kyei_8=input(">  \n")
                    if "yes" in kyei_8:
                        Step_0()
                    else:
                        exit(0)


            elif "2" in Shoice_2:
                    print("\nSarah has finally been able to lose 10 pounds and now weighs 150 just in time for her wedding.\n")
                    time.sleep(2)
                    print("\nSarah has invited you to her wedding. Would you rather go to her wedding or would you rather help someone else in need of your fitness assistance?\n")
                    Print("\Type yes to join Sarah at her wedding or no to help someone else in need.\n")
                    Answer_1=input(">")
                    if "Yes" in Answer or "yes" in Answer:
                        exit(0)
                    else:
                        print("Sarah wishes you luck in your future endeavors and hopes to never return!")
                        Step(0)

            elif "3" in Shoice_2:
                    print("\You have been fired by Sarah, she hasnt seen any improvements in her weight.\n")
                    print("Would you like to start over?\n")
                    kyei_9=input(">  \n")
                    if "yes" in kyei_9:
                        Step_0()
                    else:
                        exit(0)


            else:
                    print("Invalid command. Please try again.")
                    input("<Press enter to continue>\n")
                    Sarah()                      

                    
        
STRG()
